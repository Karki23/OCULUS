# %%
import glob
import os
import numpy as np
# %matplotlib inline
from numpy import sqrt
import matplotlib.pyplot as plt
import scipy as sp
import math
import scipy

import scipy.io as io
import pdb
import scipy.signal as sig
import h5py
import signal
import csv

file_list = glob.glob("*.txt")

final_data={'rs1':[],'rs2':[],'rs3':[],'ls1':[],'ls2':[],'ls3':[],'us1':[],'us2':[],'us3':[],'ds1':[],'ds2':[],'ds3':[]}


d0arr=[]
d1arr=[]
d2arr=[]
r0arr=[]
r1arr=[]
r2arr=[]
l0arr=[]
l1arr=[]
l2arr=[]
u0arr=[]
u1arr=[]
u2arr=[]

d0arr=np.zeros((27,4,290))
d1arr=np.zeros((27,4,290))
d2arr=np.zeros((27,4,290))

u0arr=np.zeros((27,4,290))
u1arr=np.zeros((27,4,290))
u2arr=np.zeros((27,4,290))

l0arr=np.zeros((27,4,290))
l1arr=np.zeros((27,4,290))
l2arr=np.zeros((27,4,290))

r0arr=np.zeros((27,4,290))
r1arr=np.zeros((27,4,290))
r2arr=np.zeros((27,4,290))

#print(len(file_list))
arr=[]
trial=0
flagdown=0
for file_name in file_list:
    i=0
    j=0
    array=[]
    c1=[]
    c2=[]
    c3=[]
    c4=[]
    file=open(file_name,"r")
    for line in file:
        if i>=1249:
            array=line.split(",")
            j=j+1
            c1.append(float(array[1]))
            c2.append(float(array[2]))
            c3.append(float(array[3]))
            c4.append(float(array[4]))
        i=i+1
    c1=scipy.signal.detrend(c1, axis=-1, type='linear', bp= [j for j in range(0,len(c1),290)])
    c2=scipy.signal.detrend(c2, axis=-1, type='linear', bp= [j for j in range(0,len(c1),290)])
    c3=scipy.signal.detrend(c3, axis=-1, type='linear', bp= [j for j in range(0,len(c1),290)])
    c4=scipy.signal.detrend(c4, axis=-1, type='linear', bp= [j for j in range(0,len(c1),290)])
    
#     c1=scipy.signal.detrend(c1, axis=-1, type='constant')
#     c2=scipy.signal.detrend(c2, axis=-1, type='constant')
#     c3=scipy.signal.detrend(c3, axis=-1, type='constant')
#     c4=scipy.signal.detrend(c4, axis=-1, type='constant')
    
#     c1=scipy.signal.detrend(c1, axis=-1, type='linear')
#     c2=scipy.signal.detrend(c2, axis=-1, type='linear')
#     c3=scipy.signal.detrend(c3, axis=-1, type='linear')
#     c4=scipy.signal.detrend(c4, axis=-1, type='linear')
    
    speed=int(file_name[9])-1
    
#     trial_char=file_name
#     #print(len(file_name))
#     trial=int(file_name[11])
#     if(len(trial_char)>16):
#         if(trial_char[14])=='2':
#             trial=trial+(3)*(int(file_name[7])-1)-1
        
#         elif(trial_char[14]=='3'):
#             trial=trial+(3)*(int(file_name[7])-1)-1+1
#     else:
#         trial=trial+(3)*(int(file_name[7])-1)-1+2
#     print(trial)
    
    direction=file_name[6]
    
    trial_char=file_name
    trial=3*(int(trial_char[11])-1)
    speed=int(file_name[9])-1
    loc=int(file_name[7])-1
    if(loc==0):
        if(len(file_name)>17):
            if(file_name[14]=='2'):
                addtrial=1
            elif(file_name[14]=='3'):
                addtrial=2
        else:
            addtrial=0
        trial=trial+addtrial
              
    if(loc==1):
        if(len(file_name)>17):
            if(file_name[14]=='2'):
                addtrial=1
            elif(file_name[14]=='3'):
                addtrial=2
        else:
            addtrial=0
        trial=(trial+addtrial)+9
        
    if(loc==2):
        if(len(file_name)>17):
            if(file_name[14]=='2'):
                addtrial=1
            elif(file_name[14]=='3'):
                addtrial=2
        else:
            addtrial=0
        trial=(trial+addtrial)+18
    
    #print(trial)
    
    if direction == 'r':
        dir=1
        if speed==0:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            r0arr[trial][0]=c1
            r0arr[trial][1]=c2
            r0arr[trial][2]=c3
            r0arr[trial][3]=c4
        elif speed==1:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            r1arr[trial][0]=c1
            r1arr[trial][1]=c2
            r1arr[trial][2]=c3
            r1arr[trial][3]=c4
        elif speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            r2arr[trial][0]=c1
            r2arr[trial][1]=c2
            r2arr[trial][2]=c3
            r2arr[trial][3]=c4
            
    elif direction =='d':
        dir=2
        if speed==0:
            #print(trial)
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            d0arr[trial][0]=c1
            d0arr[trial][1]=c2
            d0arr[trial][2]=c3
            d0arr[trial][3]=c4
            #print(d0arr[trial][0])

        elif speed==1:
            #print(trial)
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            #print(trial)
            d1arr[trial][0]=c1
            d1arr[trial][1]=c2
            d1arr[trial][2]=c3
            d1arr[trial][3]=c4
            #print(d1arr)
            #print(d0arr[trial][0])
            #print(c1)
        elif speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            d2arr[trial][0]=c1
            d2arr[trial][1]=c2
            d2arr[trial][2]=c3
            d2arr[trial][3]=c4
            
    if direction == 'l':
        dir=3
        if speed==0:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            l0arr[trial][0]=c1
            l0arr[trial][1]=c2
            l0arr[trial][2]=c3
            l0arr[trial][3]=c4
        elif speed==1:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            l1arr[trial][0]=c1
            l1arr[trial][1]=c2
            l1arr[trial][2]=c3
            l1arr[trial][3]=c4
        elif speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            l2arr[trial][0]=c1
            l2arr[trial][1]=c2
            l2arr[trial][2]=c3
            l2arr[trial][3]=c4
            
    elif direction =='u':
        dir=4
        if speed==0:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            u0arr[trial][0]=c1
            u0arr[trial][1]=c2
            u0arr[trial][2]=c3
            u0arr[trial][3]=c4
        elif speed==1:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            u1arr[trial][0]=c1
            u1arr[trial][1]=c2
            u1arr[trial][2]=c3
            u1arr[trial][3]=c4
        elif speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            u2arr[trial][0]=c1
            u2arr[trial][1]=c2
            u2arr[trial][2]=c3
            u2arr[trial][3]=c4


            
final_data['rs1']=r0arr
final_data['rs2']=r1arr
final_data['rs3']=r2arr

final_data['ls1']=l0arr
final_data['ls2']=l1arr
final_data['ls3']=l2arr

final_data['us1']=u0arr
final_data['us2']=u1arr
final_data['us3']=u2arr

final_data['ds1']=d0arr
final_data['ds2']=d1arr
final_data['ds3']=d2arr

# %%
# from numpy.fft import rfft
# from matplotlib.pyplot import loglog
# %matplotlib inline

# print(final_data['rs1'][0][0])
# x_Vtcr=final_data['rs1'][0][0]
# loglog(abs(rfft(x_Vtcr)))


t=[i for i in range(len(final_data['rs3'][0][0]))]

plt.subplot(2,1,1)
plt.title('Channel1, 0th trial, speed3, before bandpassing')
plt.ylabel('Right eye movement')
plt.plot(t,final_data['rs3'][7][0])


plt.subplot(2,1,2)
plt.ylabel('left eye movement')
plt.plot(t,final_data['ls3'][7][0])

# %%
from scipy.signal import butter, lfilter


def butter_bandpass_filter(data, lowcut, highcut, fs, order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq

    b, a = butter(order, [low, high], btype='band')
    y = lfilter(b, a, data)
    return y

i=0

for key,value in final_data.items():
    for trial in range(0,27):
        for channel in range(0,4):
            value[trial][channel]=butter_bandpass_filter(value[trial][channel],0.5,30,256,5)
            
# for key,value in final_data.items():
#             value=butter_bandpass_filter(value,0.5,30,256,5)

# %%
sp.io.savemat('final.mat',final_data)

# %%
# x2_Vtcr = final_data['rs1'][0][0]
# loglog(abs(rfft(x2_Vtcr)))

plt.subplot(2,1,1)
plt.title('Channel 1, speed3, after bandpassing')
plt.ylabel('right eye movement')
plt.plot(final_data['rs3'][7][0])

plt.subplot(2,1,2)
plt.ylabel('left eye movement')
plt.plot(final_data['ls3'][7][0])

plt.show()

# %%
# import pywt
# rs1a0=[]
# rs1a1=[]
# rs1a2=[]
# rs1a3=[]
# rs1a4=[]
# rs1a5=[]
# rs1a6=[]
# rs1a7=[]
# rs1a8=[]

# rs1b0=[]
# rs1b1=[]
# rs1b2=[]
# rs1b3=[]
# rs1b4=[]
# rs1b5=[]
# rs1b6=[]
# rs1b7=[]
# rs1b8=[]

# ls1a0=[]
# ls1a1=[]
# ls1a2=[]
# ls1a3=[]
# ls1a4=[]
# ls1a5=[]
# ls1a6=[]
# ls1a7=[]
# ls1a8=[]

# ls1b0=[]
# ls1b1=[]
# ls1b2=[]
# ls1b3=[]
# ls1b4=[]
# ls1b5=[]
# ls1b6=[]
# ls1b7=[]
# ls1b8=[]

# ds1a0=[]
# ds1a1=[]
# ds1a2=[]
# ds1a3=[]
# ds1a4=[]
# ds1a5=[]
# ds1a6=[]
# ds1a7=[]
# ds1a8=[]

# ds1b0=[]
# ds1b1=[]
# ds1b2=[]
# ds1b3=[]
# ds1b4=[]
# ds1b5=[]
# ds1b6=[]
# ds1b7=[]
# ds1b8=[]


# us1a0=[]
# us1a1=[]
# us1a2=[]
# us1a3=[]
# us1a4=[]
# us1a5=[]
# us1a6=[]
# us1a7=[]
# us1a8=[]

# us1b0=[]
# us1b1=[]
# us1b2=[]
# us1b3=[]
# us1b4=[]
# us1b5=[]
# us1b6=[]
# us1b7=[]
# us1b8=[]

# rs20=[]
# rs21=[]
# rs22=[]
# rs23=[]
# rs24=[]
# rs25=[]
# rs26=[]
# rs27=[]
# rs28=[] 

# ls20=[]
# ls21=[]
# ls22=[]
# ls23=[]
# ls24=[]
# ls25=[]
# ls26=[]
# ls27=[]
# ls28=[] 

# us20=[]
# us21=[]
# us22=[]
# us23=[]
# us24=[]
# us25=[]
# us26=[]
# us27=[]
# us28=[] 

# ds20=[]
# ds21=[]
# ds22=[]
# ds23=[]
# ds24=[]
# ds25=[]
# ds26=[]
# ds27=[]
# ds28=[] 

# rs30=[]
# rs31=[]
# rs32=[]
# rs33=[]
# rs34=[]
# rs35=[]
# rs36=[]
# rs37=[]
# rs38=[] 

# ls30=[]
# ls31=[]
# ls32=[]
# ls33=[]
# ls34=[]
# ls35=[]
# ls36=[]
# ls37=[]
# ls38=[] 

# ds30=[]
# ds31=[]
# ds32=[]
# ds33=[]
# ds34=[]
# ds35=[]
# ds36=[]
# ds37=[]
# ds38=[] 

# us30=[]
# us31=[]
# us32=[]
# us33=[]
# us34=[]
# us35=[]
# us36=[]
# us37=[]
# us38=[] 

# for trial in range(0,9):
#     for channel in range(0,4):
#             ra = pywt.wavedec(final_data['rs1'][trial][channel][0:290], 'db4', level=4)
#             rb = pywt.wavedec(final_data['rs1'][trial][channel][290:580], 'db4', level=4)
#             la = pywt.wavedec(final_data['ls1'][trial][channel][0:290], 'db4', level=4)
#             lb = pywt.wavedec(final_data['ls1'][trial][channel][290:580], 'db4', level=4)
#             da = pywt.wavedec(final_data['ds1'][trial][channel][0:290], 'db4', level=4)
#             db = pywt.wavedec(final_data['ds1'][trial][channel][290:580], 'db4', level=4)
#             ua = pywt.wavedec(final_data['us1'][trial][channel][0:290], 'db4', level=4)
#             ub = pywt.wavedec(final_data['us1'][trial][channel][290:580], 'db4', level=4)
#             ra=ra[1]
#             rb=rb[1]
#             la=la[1]
#             lb=lb[1]
#             da=da[1]
#             db=db[1]
#             ua=ua[1]
#             ub=ub[1]
            
#             if(trial==0):
#                 for i in range(0,len(ra)):
#                     rs1a0.append(ra[i])
#                     rs1b0.append(rb[i])
#                     ls1a0.append(la[i])
#                     ls1b0.append(lb[i])
#                     ds1a0.append(da[i])
#                     ds1b0.append(db[i])
#                     us1a0.append(ua[i])
#                     us1b0.append(ub[i])
#             if(trial==1):
#                 for i in range(0,len(ra)):
#                     rs1a1.append(ra[i])
#                     rs1b1.append(rb[i])
#                     ls1a1.append(la[i])
#                     ls1b1.append(lb[i])
#                     ds1a1.append(da[i])
#                     ds1b1.append(db[i])
#                     us1a1.append(ua[i])
#                     us1b1.append(ub[i])
#             if(trial==2):
#                 for i in range(0,len(ra)):
#                     rs1a2.append(ra[i])
#                     rs1b2.append(rb[i])
#                     ls1a2.append(la[i])
#                     ls1b2.append(lb[i])
#                     ds1a2.append(da[i])
#                     ds1b2.append(db[i])
#                     us1a2.append(ua[i])
#                     us1b2.append(ub[i])
#             if(trial==3):
#                 for i in range(0,len(ra)):
#                     rs1a3.append(ra[i])
#                     rs1b3.append(rb[i])
#                     ls1a3.append(la[i])
#                     ls1b3.append(lb[i])
#                     ds1a3.append(da[i])
#                     ds1b3.append(db[i])
#                     us1a3.append(ua[i])
#                     us1b3.append(ub[i])
#             if(trial==4):
#                 for i in range(0,len(ra)):
#                     rs1a4.append(ra[i])
#                     rs1b4.append(rb[i])
#                     ls1a4.append(la[i])
#                     ls1b4.append(lb[i])
#                     ds1a4.append(da[i])
#                     ds1b4.append(db[i])
#                     us1a4.append(ua[i])
#                     us1b4.append(ub[i])
#             if(trial==5):
#                 for i in range(0,len(ra)):
#                     rs1a5.append(ra[i])
#                     rs1b5.append(rb[i])
#                     ls1a5.append(la[i])
#                     ls1b5.append(lb[i])
#                     ds1a5.append(da[i])
#                     ds1b5.append(db[i])
#                     us1a5.append(ua[i])
#                     us1b5.append(ub[i])
#             if(trial==6):
#                 for i in range(0,len(ra)):
#                     rs1a6.append(ra[i])
#                     rs1b6.append(rb[i])
#                     ls1a6.append(la[i])
#                     ls1b6.append(lb[i])
#                     ds1a6.append(da[i])
#                     ds1b6.append(db[i])
#                     us1a6.append(ua[i])
#                     us1b6.append(ub[i])
#             if(trial==7):
#                 for i in range(0,len(ra)):
#                     rs1a7.append(ra[i])
#                     rs1b7.append(rb[i])
#                     ls1a7.append(la[i])
#                     ls1b7.append(lb[i])
#                     ds1a7.append(da[i])
#                     ds1b7.append(db[i])
#                     us1a7.append(ua[i])
#                     us1b7.append(ub[i])
#             if(trial==8):
#                 for i in range(0,len(ra)):
#                     rs1a8.append(ra[i])
#                     rs1b8.append(rb[i])
#                     ls1a8.append(la[i])
#                     ls1b8.append(lb[i])
#                     ds1a8.append(da[i])
#                     ds1b8.append(db[i])
#                     us1a8.append(ua[i])
#                     us1b8.append(ub[i])
      
                

# for trial in range(0,9):
#     for channel in range(0,4):
#             r = pywt.wavedec(final_data['rs2'][trial][channel][0:290], 'db4', level=4)
#             l = pywt.wavedec(final_data['ls2'][trial][channel][0:290], 'db4', level=4)
#             d = pywt.wavedec(final_data['ds2'][trial][channel][0:290], 'db4', level=4)
#             u = pywt.wavedec(final_data['us2'][trial][channel][0:290], 'db4', level=4)
#             r=r[1]
#             l=l[1]
#             d=d[1]
#             u=u[1]
            
#             if(trial==0):
#                 for i in range(0,len(r)):
#                     rs20.append(r[i])
#                     ls20.append(l[i])
#                     ds20.append(d[i])
#                     us20.append(u[i])
#             if(trial==1):
#                 for i in range(0,len(r)):
#                     rs21.append(r[i])
#                     ls21.append(l[i])
#                     ds21.append(d[i])
#                     us21.append(u[i])
#             if(trial==2):
#                 for i in range(0,len(r)):
#                     rs22.append(r[i])
#                     ls22.append(l[i])
#                     ds22.append(d[i])
#                     us22.append(u[i])
#             if(trial==3):
#                 for i in range(0,len(r)):
#                     rs23.append(r[i])
#                     ls23.append(l[i])
#                     ds23.append(d[i])
#                     us23.append(u[i])
#             if(trial==4):
#                 for i in range(0,len(r)):
#                     rs24.append(r[i])
#                     ls24.append(l[i])
#                     ds24.append(d[i])
#                     us24.append(u[i])
#             if(trial==5):
#                 for i in range(0,len(r)):
#                     rs25.append(r[i])
#                     ls25.append(l[i])
#                     ds25.append(d[i])
#                     us25.append(u[i])
#             if(trial==6):
#                 for i in range(0,len(r)):
#                     rs26.append(r[i])
#                     ls26.append(l[i])
#                     ds26.append(d[i])
#                     us26.append(u[i])
#             if(trial==7):
#                 for i in range(0,len(r)):
#                     rs27.append(r[i])
#                     ls27.append(l[i])
#                     ds27.append(d[i])
#                     us27.append(u[i])
#             if(trial==8):
#                 for i in range(0,len(r)):
#                     rs28.append(r[i])
#                     ls28.append(l[i])
#                     ds28.append(d[i])
#                     us28.append(u[i])
      
                



# for trial in range(0,9):
#     for channel in range(0,4):
#             r = pywt.wavedec(final_data['rs3'][trial][channel][0:290], 'db4', level=4)
#             l = pywt.wavedec(final_data['ls3'][trial][channel][0:290], 'db4', level=4)
#             d = pywt.wavedec(final_data['ds3'][trial][channel][0:290], 'db4', level=4)
#             u = pywt.wavedec(final_data['us3'][trial][channel][0:290], 'db4', level=4)
#             r=r[1]
#             l=l[1]
#             d=d[1]
#             u=u[1]
            
#             if(trial==0):
#                 for i in range(0,len(r)):
#                     rs30.append(r[i])
#                     ls30.append(l[i])
#                     ds30.append(d[i])
#                     us30.append(u[i])
#             if(trial==1):
#                 for i in range(0,len(r)):
#                     rs31.append(r[i])
#                     ls31.append(l[i])
#                     ds31.append(d[i])
#                     us31.append(u[i])
#             if(trial==2):
#                 for i in range(0,len(r)):
#                     rs32.append(r[i])
#                     ls32.append(l[i])
#                     ds32.append(d[i])
#                     us32.append(u[i])
#             if(trial==3):
#                 for i in range(0,len(r)):
#                     rs33.append(r[i])
#                     ls33.append(l[i])
#                     ds33.append(d[i])
#                     us33.append(u[i])
#             if(trial==4):
#                 for i in range(0,len(r)):
#                     rs34.append(r[i])
#                     ls34.append(l[i])
#                     ds34.append(d[i])
#                     us34.append(u[i])
#             if(trial==5):
#                 for i in range(0,len(r)):
#                     rs35.append(r[i])
#                     ls35.append(l[i])
#                     ds35.append(d[i])
#                     us35.append(u[i])
#             if(trial==6):
#                 for i in range(0,len(r)):
#                     rs36.append(r[i])
#                     ls36.append(l[i])
#                     ds36.append(d[i])
#                     us36.append(u[i])
#             if(trial==7):
#                 for i in range(0,len(r)):
#                     rs37.append(r[i])
#                     ls37.append(l[i])
#                     ds37.append(d[i])
#                     us37.append(u[i])
#             if(trial==8):
#                 for i in range(0,len(r)):
#                     rs38.append(r[i])
#                     ls38.append(l[i])
#                     ds38.append(d[i])
#                     us38.append(u[i])

# %%
# features=[rs1a0,rs1a1,rs1a2,rs1a3,rs1a4,rs1a5,rs1a6,rs1a7,rs1a8,rs1b0,rs1b1,rs1b2,rs1b3,rs1b4,rs1b5,rs1b6,rs1b7,rs1b8,ls1a0,ls1a1,ls1a2,ls1a3,ls1a4,ls1a5,ls1a6,ls1a7,ls1a8,ls1b0,ls1b1,ls1b2,ls1b3,ls1b4,ls1b5,ls1b6,ls1b7,ls1b8,ds1a0,ds1a1,ds1a2,ds1a3,ds1a4,ds1a5,ds1a6,ds1a7,ds1a8,ds1b0,ds1b1,ds1b2,ds1b3,ds1b4,ds1b5,ds1b6,ds1b7,ds1b8,us1a0,us1a1,us1a2,us1a3,us1a4,us1a5,us1a6,us1a7,us1a8,us1b0,us1b1,us1b2,us1b3,us1b4,us1b5,us1b6,us1b7,us1b8,rs20,rs21,rs22,rs23,rs24,rs25,rs26,rs27,rs28,ls20,ls21,ls22,ls23,ls24,ls25,ls26,ls27,ls28,us20,us21,us22,us23,us24,us25,us26,us27,us28,ds20,ds21,ds22,ds23,ds24,ds25,ds26,ds27,ds28,rs30,rs31,rs32,rs33,rs34,rs35,rs36,rs37,rs38,ls30,ls31,ls32,ls33,ls34,ls35,ls36,ls37,ls38,ds30,ds31,ds32,ds33,ds34,ds35,ds36,ds37,ds38,us30,us31,us32,us33,us34,us35,us36,us37,us38]

# features=np.array(features)
# l=[]
# for i in range(0,36):
#     l.append(int(0))
# for i in range(0,36):
#     l.append(int(1))
# for i in range(0,36):
#     l.append(int(2))
# for i in range(0,36):
#     l.append(int(3))

# np.array(l)

# from sklearn import preprocessing, cross_validation, svm
# import numpy as np
# from sklearn                        import metrics, svm
# from sklearn.linear_model           import LinearRegression
# from sklearn.linear_model           import LogisticRegression
# from sklearn.tree                   import DecisionTreeClassifier
# from sklearn.neighbors              import KNeighborsClassifier
# from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
# from sklearn.naive_bayes            import GaussianNB
# from sklearn.svm                    import SVC
# from sklearn import linear_model


# X = features
# y=l
# #X = preprocessing.scale(X)
# from sklearn.model_selection import train_test_split


# X_train, X_test, y_train, y_test =  cross_validation.train_test_split(X, y, test_size=0.33)

# print(y_test)

# clf = KNeighborsClassifier(n_neighbors=5)
# clf.fit(X_train, y_train)
# confidence = clf.score(X_test, y_test)
# print(confidence)

# clf = svm.SVC()
# clf.fit(X_train, y_train)
# confidence = clf.score(X_test, y_test)
# print(confidence)

# %%
# #Split data at 290 points
# r=np.ndarray(shape=(36,4,290))
# l=np.ndarray(shape=(36,4,290))
# u=np.ndarray(shape=(36,4,290))
# d=np.ndarray(shape=(36,4,290))

# trial_new=0
# trial_s2=18
# trial_s3=27
# for trial in range(0,9):
#     trial_new=2*trial
#     for channel in range(0,4):
#             ra1 =final_data['rs1'][trial][channel][0:290]
#             rb1 =final_data['rs1'][trial][channel][290:580]
#             la1 =final_data['ls1'][trial][channel][0:290]
#             lb1 =final_data['ls1'][trial][channel][290:580]
#             da1 =final_data['ds1'][trial][channel][0:290]
#             db1 =final_data['ds1'][trial][channel][290:580]
#             ua1 =final_data['us1'][trial][channel][0:290]
#             ub1 =final_data['us1'][trial][channel][290:580]

            

#             r2 =final_data['rs2'][trial][channel][0:290]
#             l2 =final_data['ls2'][trial][channel][0:290]
#             d2 =final_data['ds2'][trial][channel][0:290]
#             u2 =final_data['us2'][trial][channel][0:290]
    
#             r3 =final_data['rs3'][trial][channel][0:290]
#             l3 =final_data['ls3'][trial][channel][0:290]
#             d3 =final_data['ds3'][trial][channel][0:290]
#             u3 =final_data['us3'][trial][channel][0:290]


  
#             trial_new=2*trial
#             r[trial_new][channel]=ra1[i]
#             r[trial_new+1][channel]=(rb1[i])
#             l[trial_new][channel]=(la1[i])
#             l[trial_new+1][channel]=(lb1[i])
#             u[trial_new][channel]=(ua1[i])
#             u[trial_new+1][channel]=(ub1[i])
#             d[trial_new][channel]=(da1[i])
#             d[trial_new+1][channel]=(db1[i])

  
#             r[trial_s2][channel]=(r2[i])
#             l[trial_s2][channel]=(l2[i])
#             u[trial_s2][channel]=(u2[i])
#             d[trial_s2][channel]=(d2[i])
            
            

#             r[trial_s3][channel]=(r3[i])
#             l[trial_s3][channel]=(l3[i])
#             u[trial_s3][channel]=(u3[i])
#             d[trial_s3][channel]=(d3[i])

#     trial_s2+=1
#     trial_s3+=1
    
# direction={'left':[l],'right':[r],'up':[l],'down':[d]}
# sp.io.savemat('direc.mat',direction)

# %%
#This code extracts the six feature sets and store the outputs as '.mat' files. It takes the output generated by the filter signals code to 
#give the outputs.

import numpy as np
import scipy.io as spi 
#from biosppy.signals.eeg import get_power_features
from scipy.signal import welch
from time import time
import pyeeg
import pywt
import math
from scipy.signal import correlate
from numpy.fft import fft
from scipy import stats as st

#The below two functions are used to generate the Discrete wavelet transform features.
def wenergy(arr, wavlet, levelOfDecomp):
    deCompMat = wt(arr,wavlet,levelOfDecomp)
    en = []
    ea = 0
    ed = []
    for i in range(len(deCompMat)):
        en.append(sum(j*j for j in deCompMat[i]))
    Ten = sum(en)
    for i in range(len(deCompMat)):
        if i == len(deCompMat)-1:
            ea = (en[i]/Ten)*100
        else:
            ed.append((en[i]/Ten)*100)
    retval = []
    retval.append(ea)
    retval.extend(ed)
    return retval

def wt(arr, wavlet, levelOfDecomp):
    cA, cD = pywt.dwt(arr, wavlet)
    deCompMat = []
    deCompMat.append(cD.tolist())
    if(levelOfDecomp > math.log(len(arr))/math.log(2)):
        print('invalid levels of decomposition')
    elif (levelOfDecomp>1 and levelOfDecomp<=math.log(len(arr))/math.log(2)):
        for i in range(1,levelOfDecomp):
            cA, cD = pywt.dwt(cA, wavlet)
            if (i < levelOfDecomp):
                deCompMat.append(cD.tolist())
            elif (i==levelOfDecomp):
                deCompMat.append(cD.tolist())
                deCompMat.append(cA.tolist())
    return deCompMat
feature_set=[]
outMatrix=['Right.mat','Left.mat','Up.mat','Down.mat']

flagr=0
flagl=0
flagu=0
flagd=0

ind1=[0, 1]
ind2=[2, 3]
features=[]
direc=['rs1','rs2','rs3','ls1','ls2','ls3','us1','us2','us3','ds1','ds2','ds3']

for h in range(len(direc)):#participants, for us its 4 directions
    #print(h)
    #Initialization of array space to store the features.
    m=final_data[direc[h]]
    featuresHjorth=np.ndarray(shape=(27,12))#96-features
    featuresCorrelation=np.ndarray(shape=(27,2))
    featuresPSD=np.ndarray(shape=(27,12))
    featuresDWT=np.ndarray(shape=(27,20))#160->5*no_of_bands
    featuresEnergy=np.ndarray(shape=(27,20))
    featuresStatistical=np.ndarray(shape=(27,20))#160->5 features * 32 channels


    datData=m

    for i in range(27):#trials
        
        localHjorth=[]
        localCorrelation=[]
        localPSD=[]
        localDWT=[]
        localEnergy=[]
        localStat=[]

        # The below for loop generates the Hjorth,PSD and DWT features for a given trial.They work on the unfiltered dataset. 
        for j in range(4):#channels
            arr=m[i][j]
            freq,PSD=welch(arr)
            PSD=PSD.tolist()
            maxFreq=freq[PSD.index(max(PSD))]
            localHjorth=localHjorth+[np.var(arr)]+list(pyeeg.hjorth(arr))
            localPSD=localPSD+[np.mean(PSD),np.var(PSD),maxFreq]
            #print(i,j,direc[h])
            localDWT=localDWT+wenergy(arr,"db4",5)

        # The below for loop gnerates the correlation features for a given trial. They work on the unfiltered signals.
        for j in range(2):#sym channe
            localCorrelation=localCorrelation+[max(correlate(final_data[direc[h]][i][ind1[j]],final_data[direc[h]][i][ind2[j]]))]

        featuresHjorth[i,:]=localHjorth
        featuresCorrelation[i,:]=localCorrelation
        featuresDWT[i,:]=localDWT
        featuresPSD[i,:]=localPSD

        # The below for loop generates the Energy features.They work on the five filtered frequency bands.
        """for j in range(4):
            fftDelta=fft(datDelta[i,j,:])
            fftTheta=fft(datTheta[i,j,:])
            fftAlpha=fft(datAlpha[i,j,:])
            fftBeta=fft(datBeta[i,j,:])
            fftGamma=fft(datGamma[i,j,:])
            localEnergy=localEnergy+[sum(np.square(np.abs(fftDelta)))/float(len(fftDelta))]+[sum(np.square(np.abs(fftAlpha)))/float(len(fftAlpha))]+[sum(np.square(np.abs(fftTheta)))/float(len(fftTheta))]+[sum(np.square(np.abs(fftBeta)))/float(len(fftBeta))]+[sum(np.square(np.abs(fftGamma)))/float(len(fftGamma))]

        featuresEnergy[i,:]=localEnergy

        #The below for loop generates the Statistical features. They work on the five filtered frequency bands.

        for j in range(4):
            arrD=datDelta[i,j,:]
            arrT=datTheta[i,j,:]
            arrA=datAlpha[i,j,:]
            arrB=datBeta[i,j,:]
            arrG=datGamma[i,j,:]

            localStat=localStat+[sum(arrD)/float(len(arrD)),sum(arrT)/float(len(arrT)),sum(arrA)/float(len(arrA)),sum(arrB)/float(len(arrB)),sum(arrG)/float(len(arrG))]+[np.sqrt(np.mean(np.square(arrD))),np.sqrt(np.mean(np.square(arrT))),np.sqrt(np.mean(np.square(arrA))),np.sqrt(np.mean(np.square(arrB))),np.sqrt(np.mean(np.square(arrG)))]+[st.skew(arrD),st.skew(arrT),st.skew(arrA),st.skew(arrB),st.skew(arrG)]+[st.kurtosis(arrD),st.kurtosis(arrT),st.kurtosis(arrA),st.kurtosis(arrB),st.kurtosis(arrG)]
        featuresStatistical[i,:]=localStat"""
        #s={'hjorth':featuresHjorth,'correlation':featuresCorrelation,'PSD':featuresPSD,'DWT':featuresDWT} #,'energy':featuresEnergy,'stat':featuresStatistical}
        #spi.savemat(outMatrix[h],s)
        #features.append()
        #print(np.shape(featuresCorrelation))
        #print(direc[h])
     
    if(direc[h][0]=='r'):
        if(flagr==0):
            s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[]}
            s['hjorth']=featuresHjorth
            s['correlation']=featuresCorrelation
            s['PSD']=featuresPSD
            s['DWT']=featuresDWT
            flagr+=1#flag is to tell if rs1,rs2,rs3 is finished or not
        else:
            #s['hjorth'].numpy.append(featuresHjorth)
            s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
            s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
            s['PSD']=np.vstack((s['PSD'],featuresPSD))
            s['DWT']=np.vstack((s['DWT'],featuresDWT))
            flagr+=1
            if(flagr==3):
                spi.savemat(outMatrix[0],s)
                flagr=0


    if(direc[h][0]=='l'):
        if(flagl==0):
            s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[]}
            s['hjorth']=featuresHjorth
            s['correlation']=featuresCorrelation
            s['PSD']=featuresPSD
            s['DWT']=featuresDWT
            flagl+=1
        else:
            #s['hjorth'].numpy.append(featuresHjorth)
            s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
            s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
            s['PSD']=np.vstack((s['PSD'],featuresPSD))
            s['DWT']=np.vstack((s['DWT'],featuresDWT))
            flagl+=1
            if(flagl==3):
                spi.savemat(outMatrix[1],s)
                flagl=0




    if(direc[h][0]=='u'):
        if(flagu==0):
            s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[]}
            s['hjorth']=featuresHjorth
            s['correlation']=featuresCorrelation
            s['PSD']=featuresPSD
            s['DWT']=featuresDWT
            flagu+=1
        else:
            #s['hjorth'].numpy.append(featuresHjorth)
            s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
            s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
            s['PSD']=np.vstack((s['PSD'],featuresPSD))
            s['DWT']=np.vstack((s['DWT'],featuresDWT))
            flagu+=1
            if(flagu==3):
                spi.savemat(outMatrix[2],s)
                flagu=0



    if(direc[h][0]=='d'):
        if(flagd==0):
            s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[]}
            s['hjorth']=featuresHjorth
            s['correlation']=featuresCorrelation
            s['PSD']=featuresPSD
            s['DWT']=featuresDWT
            flagd+=1
        else:
            #s['hjorth'].numpy.append(featuresHjorth)
            s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
            s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
            s['PSD']=np.vstack((s['PSD'],featuresPSD))
            s['DWT']=np.vstack((s['DWT'],featuresDWT))
            flagd+=1
            if(flagd==3):
                spi.savemat(outMatrix[3],s)
                flagd=0

# %%
print(np.shape(s['hjorth']))
# Out:
# (81, 12)

# %%
import scipy.io
matr = scipy.io.loadmat('Right.mat')
matl = scipy.io.loadmat('Left.mat')
matu = scipy.io.loadmat('Up.mat')
matd = scipy.io.loadmat('Down.mat')

hjorth_feature=np.ndarray(shape=(324,12))
hjorth_feature = np.vstack((matl['hjorth'],matr['hjorth'],matu['hjorth'],matd['hjorth']))
#print(hjorth_feature)
correlation_feature=np.ndarray(shape=(324,2))
correlation_feature = np.vstack((matl['correlation'],matr['correlation'],matu['correlation'],matd['correlation']))

PSD_feature=np.ndarray(shape=(324,12))
PSD_feature = np.vstack((matl['PSD'],matr['PSD'],matu['PSD'],matd['PSD']))

DWT_feature=np.ndarray(shape=(324,20))
DWT_feature = np.vstack((matl['DWT'],matr['DWT'],matu['DWT'],matd['DWT']))

hjorth_feature=np.array(hjorth_feature)
l=[]
for i in range(0,81):
    l.append(int(0))
for i in range(0,81):
    l.append(int(1))
for i in range(0,81):
    l.append(int(2))
for i in range(0,81):
    l.append(int(3))

l=np.array(l)

from sklearn import preprocessing, cross_validation, svm
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn import linear_model
import statistics 

X = hjorth_feature
X=preprocessing.scale(X)
y=l
score=[]
print('Feature : Hjorth')
print('4 Class problem')

clf=KNeighborsClassifier(n_neighbors=4)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('KNN:',statistics.mean(score))
score=[]

clf = svm.SVC()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('SVC:',statistics.mean(score))
score=[]

from sklearn.neural_network import MLPClassifier

clf=MLPClassifier()#100,alpha=0.0001,max_iter=1350)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#    print(np.shape(hjorth_feature)) print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
print(score)
print('MLP:',statistics.mean(score))


# X_train, X_test, y_train, y_test =  cross_validation.train_test_split(X, y, test_size=0.2)
# clf = MLPClassifier()
# clf.fit(X_train, y_train)
# confidence = clf.score(X_test, y_test)
# print(confidence)
# Out:
# Feature : Hjorth
# 4 Class problem
# KNN: 0.355698529412
# SVC: 0.420036764706
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# [0.29411764705882354, 0.28125, 0.453125, 0.46875, 0.609375]
# MLP: 0.421323529412

# %%
import scipy.io
matr = scipy.io.loadmat('Right.mat')
matl = scipy.io.loadmat('Left.mat')
matu = scipy.io.loadmat('Up.mat')
matd = scipy.io.loadmat('Down.mat')

hjorth_feature=np.ndarray(shape=(162,12))
hjorth_feature = np.vstack((matl['hjorth'],matr['hjorth']))
#print(hjorth_feature)
correlation_feature=np.ndarray(shape=(162,2))
correlation_feature = np.vstack((matl['correlation'],matr['correlation']))

PSD_feature=np.ndarray(shape=(162,12))
PSD_feature = np.vstack((matl['PSD'],matr['PSD']))

DWT_feature=np.ndarray(shape=(162,20))
DWT_feature = np.vstack((matl['DWT'],matr['DWT']))

hjorth_feature=np.array(hjorth_feature)
l=[]
for i in range(0,81):
    l.append(int(0))
for i in range(0,81):
    l.append(int(1))

l=np.array(l)

from sklearn import preprocessing, cross_validation, svm
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn import linear_model
import statistics 

X = DWT_feature
X=preprocessing.scale(X)
y=l
score=[]
print('Feature : Hjorth')
print('2 Class problem (L-R)')

clf=KNeighborsClassifier(n_neighbors=4)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('KNN:',statistics.mean(score))
score=[]

clf = svm.SVC()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('SVC:',statistics.mean(score))
score=[]

clf=MLPClassifier()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#    print(np.shape(hjorth_feature)) print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('MLP:',statistics.mean(score))
# Out:
# Feature : Hjorth
# 2 Class problem (L-R)
# KNN: 0.597426470588
# SVC: 0.580514705882
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# MLP: 0.629779411765

# %%
import scipy.io
matr = scipy.io.loadmat('Right.mat')
matl = scipy.io.loadmat('Left.mat')
matu = scipy.io.loadmat('Up.mat')
matd = scipy.io.loadmat('Down.mat')

hjorth_feature=np.ndarray(shape=(162,12))
hjorth_feature = np.vstack((matu['hjorth'],matd['hjorth']))
#print(hjorth_feature)
correlation_feature=np.ndarray(shape=(162,2))
correlation_feature = np.vstack((matu['correlation'],matd['correlation']))

PSD_feature=np.ndarray(shape=(162,12))
PSD_feature = np.vstack((matu['PSD'],matd['PSD']))

DWT_feature=np.ndarray(shape=(162,20))
DWT_feature = np.vstack((matu['DWT'],matd['DWT']))

hjorth_feature=np.array(hjorth_feature)
l=[]
for i in range(0,81):
    l.append(int(0))
for i in range(0,81):
    l.append(int(1))

l=np.array(l)

from sklearn import preprocessing, cross_validation, svm
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn import linear_model
import statistics 

X = hjorth_feature
X=preprocessing.scale(X)
y=l
score=[]
print('Feature : Hjorth')
print('2 Class problem (U-D)')

clf=KNeighborsClassifier(n_neighbors=4)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('KNN:',statistics.mean(score))
score=[]

clf = svm.SVC()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('SVC:',statistics.mean(score))
score=[]

clf=MLPClassifier()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#    print(np.shape(hjorth_feature)) print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('MLP:',statistics.mean(score))
# Out:
# Feature : Hjorth
# 2 Class problem (U-D)
# KNN: 0.440073529412
# SVC: 0.55625
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# MLP: 0.569852941176

# %%
import scipy.io
matr = scipy.io.loadmat('Right.mat')
matl = scipy.io.loadmat('Left.mat')
matu = scipy.io.loadmat('Up.mat')
matd = scipy.io.loadmat('Down.mat')

hjorth_feature=np.ndarray(shape=(324,12))
hjorth_feature = np.vstack((matl['hjorth'],matr['hjorth'],matu['hjorth'],matd['hjorth']))
#print(hjorth_feature)
correlation_feature=np.ndarray(shape=(324,2))
correlation_feature = np.vstack((matl['correlation'],matr['correlation'],matu['correlation'],matd['correlation']))

PSD_feature=np.ndarray(shape=(324,12))
PSD_feature = np.vstack((matl['PSD'],matr['PSD'],matu['PSD'],matd['PSD']))

DWT_feature=np.ndarray(shape=(324,20))
DWT_feature = np.vstack((matl['DWT'],matr['DWT'],matu['DWT'],matd['DWT']))

hjorth_feature=np.array(hjorth_feature)
l=[]
for i in range(0,81):
    l.append(int(0))
for i in range(0,81):
    l.append(int(1))
for i in range(0,81):
    l.append(int(2))
for i in range(0,81):
    l.append(int(3))

l=np.array(l)

from sklearn import preprocessing, cross_validation, svm
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn import linear_model
import statistics 

X = DWT_feature
print('Feature : DWT')
X=preprocessing.scale(X)
y=l
score=[]
print('4 Class problem')

clf=KNeighborsClassifier(n_neighbors=4)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('KNN:',statistics.mean(score))
score=[]

clf = svm.SVC()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('SVC:',statistics.mean(score))
score=[]

from sklearn.neural_network import MLPClassifier

clf=MLPClassifier()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#    print(np.shape(hjorth_feature)) print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('MLP:',statistics.mean(score))
# Out:
# Feature : DWT
# 4 Class problem
# KNN: 0.329963235294
# SVC: 0.367830882353
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# MLP: 0.386764705882

# %%
import scipy.io
matr = scipy.io.loadmat('Right.mat')
matl = scipy.io.loadmat('Left.mat')
matu = scipy.io.loadmat('Up.mat')
matd = scipy.io.loadmat('Down.mat')

hjorth_feature=np.ndarray(shape=(162,12))
hjorth_feature = np.vstack((matl['hjorth'],matr['hjorth']))
#print(hjorth_feature)
correlation_feature=np.ndarray(shape=(162,2))
correlation_feature = np.vstack((matl['correlation'],matr['correlation']))

PSD_feature=np.ndarray(shape=(162,12))
PSD_feature = np.vstack((matl['PSD'],matr['PSD']))

DWT_feature=np.ndarray(shape=(162,20))
DWT_feature = np.vstack((matl['DWT'],matr['DWT']))

hjorth_feature=np.array(hjorth_feature)
l=[]
for i in range(0,81):
    l.append(int(0))
for i in range(0,81):
    l.append(int(1))

l=np.array(l)

from sklearn import preprocessing, cross_validation, svm
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn import linear_model
import statistics 

X = DWT_feature
X=preprocessing.scale(X)
y=l
score=[]
print('Feature : DWT')
print('2 Class problem (L-R)')

clf=KNeighborsClassifier(n_neighbors=4)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('KNN:',statistics.mean(score))
score=[]

clf = svm.SVC()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('SVC:',statistics.mean(score))
score=[]

clf=MLPClassifier()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#    print(np.shape(hjorth_feature)) print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('MLP:',statistics.mean(score))
# Out:
# Feature : DWT
# 2 Class problem (L-R)
# KNN: 0.597426470588
# SVC: 0.580514705882
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# MLP: 0.630147058824

# %%
import scipy.io
matr = scipy.io.loadmat('Right.mat')
matl = scipy.io.loadmat('Left.mat')
matu = scipy.io.loadmat('Up.mat')
matd = scipy.io.loadmat('Down.mat')

hjorth_feature=np.ndarray(shape=(162,12))
hjorth_feature = np.vstack((matu['hjorth'],matd['hjorth']))
#print(hjorth_feature)
correlation_feature=np.ndarray(shape=(162,2))
correlation_feature = np.vstack((matu['correlation'],matd['correlation']))

PSD_feature=np.ndarray(shape=(162,12))
PSD_feature = np.vstack((matu['PSD'],matd['PSD']))

DWT_feature=np.ndarray(shape=(162,20))
DWT_feature = np.vstack((matu['DWT'],matd['DWT']))

hjorth_feature=np.array(hjorth_feature)
l=[]
for i in range(0,81):
    l.append(int(0))
for i in range(0,81):
    l.append(int(1))

l=np.array(l)

from sklearn import preprocessing, cross_validation, svm
import numpy as np
from sklearn                        import metrics, svm
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn import linear_model
import statistics 

X = DWT_feature
X=preprocessing.scale(X)
y=l
score=[]
print('Feature : DWT')
print('2 Class problem (U-D)')

clf=KNeighborsClassifier(n_neighbors=4)
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('KNN:',statistics.mean(score))
score=[]

clf = svm.SVC()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#     print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('SVC:',statistics.mean(score))
score=[]

clf=MLPClassifier()
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, random_state=None)
# X is the feature set and y is the target
for train_index, val_index in skf.split(X,y): 
#     print("Train:", train_index, "Validation:", val_index) 
    X_train, X_test = X[train_index], X[val_index] 
    y_train, y_test = y[train_index], y[val_index]
#    print(np.shape(hjorth_feature)) print(y_train)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    score.append(confidence)
#print(score)
print('MLP:',statistics.mean(score))
# Out:
# Feature : DWT
# 2 Class problem (U-D)
# KNN: 0.568382352941
# SVC: 0.555882352941
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# MLP: 0.562867647059

# %%
#PSD (own code)

# %%
# from numpy.fft import rfft
# from matplotlib.pyplot import loglog
# %matplotlib inline

# new_data=np.ndarray(shape=(9,4))
# new_data=final_data


# def butter_bandpass_filter(data, lowcut, highcut, fs, order=2):
#     nyq = 0.5 * fs
#     low = lowcut /nyq
#     high = highcut/nyq
#     b, a = butter(order, [low, high], btype='band')
#     #print(b,a)
#     y = lfilter(b, a, data)
#     return y
# #new_left=np.vstack((new_data['ls1'][:][0:290],new_data['ls2'][:][0:290],new_data['ls3']))

# %%
# from numpy.fft import rfft
# from matplotlib.pyplot import loglog
# wav=['al','th','ga','de','be','si']
# new_data={'rs1al':[],'rs2al':[],'rs3al':[],'ls1al':[],'ls2al':[],'ls3al':[],'us1al':[],'us2al':[],'us3al':[],'ds1al':[],'ds2al':[],'ds3al':[],'rs1be':[],'rs2be':[],'rs3be':[],'ls1be':[],'ls2be':[],'ls3be':[],'us1be':[],'us2be':[],'us3be':[],'ds1be':[],'ds2be':[],'ds3be':[],'rs1th':[],'rs2th':[],'rs3th':[],'ls1th':[],'ls2th':[],'ls3th':[],'us1th':[],'us2th':[],'us3th':[],'ds1th':[],'ds2th':[],'ds3th':[],'rs1de':[],'rs2de':[],'rs3de':[],'ls1de':[],'ls2de':[],'ls3de':[],'us1de':[],'us2de':[],'us3de':[],'ds1de':[],'ds2de':[],'ds3de':[],'rs1ga':[],'rs2ga':[],'rs3ga':[],'ls1ga':[],'ls2ga':[],'ls3ga':[],'us1ga':[],'us2ga':[],'us3ga':[],'ds1ga':[],'ds2ga':[],'ds3ga':[],'rs1si':[],'rs2si':[],'rs3si':[],'ls1si':[],'ls2si':[],'ls3si':[],'us1si':[],'us2si':[],'us3si':[],'ds1si':[],'ds2si':[],'ds3si':[],}
# for dir in direc:
#     for wave in wav:
#         if(dir[2]=='1'):
#             new_data[dir+wave]=np.ndarray(shape=(9,4,386))
#         if(dir[2]=='2'):
#             new_data[dir+wave]=np.ndarray(shape=(9,4,206))
#         if(dir[2]=='3'):
#             new_data[dir+wave]=np.ndarray(shape=(9,4,146))

# for dir in direc:
#     for i in range(9):
#         for j in range(4):
#             new_data[dir+'al'][i][j] = (abs(rfft(final_data[dir][i][j])))
#             new_data[dir+'be'][i][j] = (abs(rfft(final_data[dir][i][j])))
#             new_data[dir+'th'][i][j] = (abs(rfft(final_data[dir][i][j])))
#             new_data[dir+'ga'][i][j] = (abs(rfft(final_data[dir][i][j])))
#             new_data[dir+'de'][i][j] = (abs(rfft(final_data[dir][i][j])))
#             new_data[dir+'si'][i][j] = (abs(rfft(final_data[dir][i][j])))
            
#             new_data[dir+'al'][i][j] = butter_bandpass_filter(new_data[dir+'al'][i][j], 8.1, 12.0, 256)
#             new_data[dir+'be'][i][j] = butter_bandpass_filter(new_data[dir+'al'][i][j], 16.0, 36.0, 256)
#             new_data[dir+'ga'][i][j] = butter_bandpass_filter(new_data[dir+'al'][i][j], 36.1, 80.0, 256)
#             new_data[dir+'de'][i][j] = butter_bandpass_filter(new_data[dir+'al'][i][j], 0.0, 4.0, 256)
#             new_data[dir+'si'][i][j] = butter_bandpass_filter(new_data[dir+'al'][i][j], 12.1, 16.0, 256)
#             new_data[dir+'th'][i][j] = butter_bandpass_filter(new_data[dir+'al'][i][j], 4.1, 8.0, 256)

# %%
# #This code extracts the six feature sets and store the outputs as '.mat' files. It takes the output generated by the filter signals code to 
# #give the outputs.

# import numpy as np
# import scipy.io as spi 
# #from biosppy.signals.eeg import get_power_features
# from scipy.signal import welch
# from time import time
# import pyeeg
# import pywt
# import math
# from scipy.signal import correlate
# from numpy.fft import fft
# from scipy import stats as st

# #The below two functions are used to generate the Discrete wavelet transform features.
# def wenergy(arr, wavlet, levelOfDecomp):
#     deCompMat = wt(arr,wavlet,levelOfDecomp)
#     en = []
#     ea = 0
#     ed = []
#     for i in range(len(deCompMat)):
#         en.append(sum(j*j for j in deCompMat[i]))
#     Ten = sum(en)
#     for i in range(len(deCompMat)):
#         if i == len(deCompMat)-1:
#             ea = (en[i]/Ten)*100
#         else:
#             ed.append((en[i]/Ten)*100)
#     retval = []
#     retval.append(ea)
#     retval.extend(ed)
#     return retval

# def wt(arr, wavlet, levelOfDecomp):
#     cA, cD = pywt.dwt(arr, wavlet)
#     deCompMat = []
#     deCompMat.append(cD.tolist())
#     if(levelOfDecomp > math.log(len(arr))/math.log(2)):
#         print('invalid levels of decomposition')
#     elif (levelOfDecomp>1 and levelOfDecomp<=math.log(len(arr))/math.log(2)):
#         for i in range(1,levelOfDecomp):
#             cA, cD = pywt.dwt(cA, wavlet)
#             if (i < levelOfDecomp):
#                 deCompMat.append(cD.tolist())
#             elif (i==levelOfDecomp):
#                 deCompMat.append(cD.tolist())
#                 deCompMat.append(cA.tolist())
#     return deCompMat
# feature_set=[]
# outMatrix=['Right.mat','Left.mat','Up.mat','Down.mat']

# flagr=0
# flagl=0
# flagu=0
# flagd=0

# ind1=[0, 1]
# ind2=[2, 3]
# features=[]
# direc=['rs1','rs2','rs3','ls1','ls2','ls3','us1','us2','us3','ds1','ds2','ds3']

# for h in range(len(direc)):#participants, for us its 4 directions
#     #print(h)
#     #Initialization of array space to store the features.
#     m=final_data[direc[h]]
#     featuresHjorth=np.ndarray(shape=(9,12))#96-features
#     featuresCorrelation=np.ndarray(shape=(9,2))
#     featuresPSD=np.ndarray(shape=(9,12))
#     featuresDWT=np.ndarray(shape=(9,20))#160->5*no_of_bands
#     featuresEnergy=np.ndarray(shape=(9,20))
#     featuresStatistical=np.ndarray(shape=(9,80))#160->5 features * 32 channels


#     datData=m
#     datDelta=new_data[direc[h]+'de']
#     datTheta=new_data[direc[h]+'th']
#     datAlpha=new_data[direc[h]+'al']
#     datBeta=new_data[direc[h]+'be']
#     datGamma=new_data[direc[h]+'ga']
#     for i in range(9):#trials
        
#         localHjorth=[]
#         localCorrelation=[]
#         localPSD=[]
#         localDWT=[]
#         localEnergy=[]
#         localStat=[]

#         # The below for loop generates the Hjorth,PSD and DWT features for a given trial.They work on the unfiltered dataset. 
#         for j in range(4):#channels
#             arr=m[i][j]
#             freq,PSD=welch(arr)
#             PSD=PSD.tolist()
#             maxFreq=freq[PSD.index(max(PSD))]
#             localHjorth=localHjorth+[np.var(arr)]+list(pyeeg.hjorth(arr))
#             localPSD=localPSD+[np.mean(PSD),np.var(PSD),maxFreq]
#             localDWT=localDWT+wenergy(arr,"db4",5)

#         # The below for loop gnerates the correlation features for a given trial. They work on the unfiltered signals.
#         for j in range(2):#sym channe
#             localCorrelation=localCorrelation+[max(correlate(final_data[direc[h]][i][ind1[j]],final_data[direc[h]][i][ind2[j]]))]

#         featuresHjorth[i,:]=localHjorth
#         featuresCorrelation[i,:]=localCorrelation
#         featuresDWT[i,:]=localDWT
#         featuresPSD[i,:]=localPSD
#         #print(np.shape(featuresHjorth))
        
#         # The below for loop generates the Energy features.They work on the five filtered frequency bands.
#         for j in range(4):
#             fftDelta=fft(datDelta[i,j,:])
#             fftTheta=fft(datTheta[i,j,:])
#             fftAlpha=fft(datAlpha[i,j,:])
#             fftBeta=fft(datBeta[i,j,:])
#             fftGamma=fft(datGamma[i,j,:])
#             localEnergy=localEnergy+[sum(np.square(np.abs(fftDelta)))/float(len(fftDelta))]+[sum(np.square(np.abs(fftAlpha)))/float(len(fftAlpha))]+[sum(np.square(np.abs(fftTheta)))/float(len(fftTheta))]+[sum(np.square(np.abs(fftBeta)))/float(len(fftBeta))]+[sum(np.square(np.abs(fftGamma)))/float(len(fftGamma))]

#         featuresEnergy[i,:]=localEnergy

#         #The below for loop generates the Statistical features. They work on the five filtered frequency bands.

#         for j in range(4):
#             arrD=datDelta[i,j,:]
#             arrT=datTheta[i,j,:]
#             arrA=datAlpha[i,j,:]
#             arrB=datBeta[i,j,:]
#             arrG=datGamma[i,j,:]

#             localStat=localStat+[sum(arrD)/float(len(arrD)),sum(arrT)/float(len(arrT)),sum(arrA)/float(len(arrA)),sum(arrB)/float(len(arrB)),sum(arrG)/float(len(arrG))]+[np.sqrt(np.mean(np.square(arrD))),np.sqrt(np.mean(np.square(arrT))),np.sqrt(np.mean(np.square(arrA))),np.sqrt(np.mean(np.square(arrB))),np.sqrt(np.mean(np.square(arrG)))]+[st.skew(arrD),st.skew(arrT),st.skew(arrA),st.skew(arrB),st.skew(arrG)]+[st.kurtosis(arrD),st.kurtosis(arrT),st.kurtosis(arrA),st.kurtosis(arrB),st.kurtosis(arrG)]
#         #print(np.shape(localStat))
        
#         #print(np.shape(featuresStatistical))
#         featuresStatistical[i,:]=localStat
#         #print(np.shape(featuresStatistical))
#         #s={'hjorth':featuresHjorth,'correlation':featuresCorrelation,'PSD':featuresPSD,'DWT':featuresDWT} #,'energy':featuresEnergy,'stat':featuresStatistical}
#         #spi.savemat(outMatrix[h],s)
#         #features.append()
#         #print(np.shape(featuresCorrelation))
#         #print(direc[h])
     
#         if(direc[h][0]=='r'):
#             if(flagr==0):
#                 s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[],'energy':[],'stat':[]}
#                 s['hjorth']=featuresHjorth
#                 s['correlation']=featuresCorrelation
#                 s['PSD']=featuresPSD
#                 s['DWT']=featuresDWT
#                 s['energy']=featuresEnergy
#                 s['stat']=featuresStatistical
#                 flagr+=1
#             else:
#                 #s['hjorth'].numpy.append(featuresHjorth)
#                 s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
#                 s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
#                 s['PSD']=np.vstack((s['PSD'],featuresPSD))
#                 s['DWT']=np.vstack((s['DWT'],featuresDWT))
#                 s['energy']=np.vstack((s['energy'],featuresEnergy))
#                 s['stat']=np.vstack((s['stat'],featuresStatistical))
#                 flagr+=1
#                 if(flagr==3):
#                     spi.savemat(outMatrix[0],s)
#                     flagr=0


#         if(direc[h][0]=='l'):
#             if(flagl==0):
#                 s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[],'energy':[],'stat':[]}
#                 s['hjorth']=featuresHjorth
#                 s['correlation']=featuresCorrelation
#                 s['PSD']=featuresPSD
#                 s['DWT']=featuresDWT
#                 s['energy']=featuresEnergy
#                 s['stat']=featuresStatistical

#                 flagl+=1
#             else:
#                 #s['hjorth'].numpy.append(featuresHjorth)
#                 s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
#                 s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
#                 s['PSD']=np.vstack((s['PSD'],featuresPSD))
#                 s['DWT']=np.vstack((s['DWT'],featuresDWT))
#                 s['energy']=np.vstack((s['energy'],featuresEnergy))
#                 s['stat']=np.vstack((s['stat'],featuresStatistical))
#                 flagl+=1
#                 if(flagl==3):
#                     spi.savemat(outMatrix[1],s)
#                     flagl=0




#         if(direc[h][0]=='u'):
#             if(flagu==0):
#                 s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[],'energy':[],'stat':[]}
#                 s['hjorth']=featuresHjorth
#                 s['correlation']=featuresCorrelation
#                 s['PSD']=featuresPSD
#                 s['DWT']=featuresDWT
#                 s['energy']=featuresEnergy
#                 s['stat']=featuresStatistical
#                 flagu+=1
#             else:
#                 #s['hjorth'].numpy.append(featuresHjorth)
#                 s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
#                 s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
#                 s['PSD']=np.vstack((s['PSD'],featuresPSD))
#                 s['DWT']=np.vstack((s['DWT'],featuresDWT))
#                 s['energy']=np.vstack((s['energy'],featuresEnergy))
#                 s['stat']=np.vstack((s['stat'],featuresStatistical))
#                 flagu+=1
#                 if(flagu==3):
#                     spi.savemat(outMatrix[2],s)
#                     flagu=0



#         if(direc[h][0]=='d'):
#             if(flagd==0):
#                 s={'hjorth':[],'correlation':[],'PSD':[],'DWT':[],'energy':[],'stat':[]}
#                 s['hjorth']=featuresHjorth
#                 s['correlation']=featuresCorrelation
#                 s['PSD']=featuresPSD
#                 s['DWT']=featuresDWT
#                 s['energy']=featuresEnergy
#                 s['stat']=featuresStatistical
#                 flagd+=1
#             else:
#                 #s['hjorth'].numpy.append(featuresHjorth)
#                 s['hjorth']=np.vstack((s['hjorth'],featuresHjorth))
#                 s['correlation']=np.vstack((s['correlation'],featuresCorrelation))
#                 s['PSD']=np.vstack((s['PSD'],featuresPSD))
#                 s['DWT']=np.vstack((s['DWT'],featuresDWT))
#                 s['energy']=np.vstack((s['energy'],featuresEnergy))
#                 s['stat']=np.vstack((s['stat'],featuresStatistical))
#                 flagd+=1
#                 if(flagd==3):
#                     spi.savemat(outMatrix[3],s)
#                     flagd=0

# %%
# import scipy.io
# matr = scipy.io.loadmat('Right.mat')
# matl = scipy.io.loadmat('Left.mat')
# matu = scipy.io.loadmat('Up.mat')
# matd = scipy.io.loadmat('Down.mat')

# hjorth_feature=np.ndarray(shape=(108,12))
# hjorth_feature = np.vstack((matl['hjorth'],matr['hjorth'],matu['hjorth'],matd['hjorth']))
# #print(hjorth_feature)
# correlation_feature=np.ndarray(shape=(108,2))
# correlation_feature = np.vstack((matl['correlation'],matr['correlation'],matu['correlation'],matd['correlation']))

# PSD_feature=np.ndarray(shape=(108,12))
# PSD_feature = np.vstack((matl['PSD'],matr['PSD'],matu['PSD'],matd['PSD']))

# DWT_feature=np.ndarray(shape=(108,20))
# DWT_feature = np.vstack((matl['DWT'],matr['DWT'],matu['DWT'],matd['DWT']))

# energy_feature=np.ndarray(shape=(108,20))
# energy_feature = np.vstack((matl['energy'],matr['energy'],matu['energy'],matd['energy']))

# stat_feature=np.ndarray(shape=(108,80))
# stat_feature = np.vstack((matl['stat'],matr['stat'],matu['stat'],matd['stat']))

# hjorth_feature=np.array(hjorth_feature)
# l=[]
# for i in range(0,27):
#     l.append(int(0))
# for i in range(0,27):
#     l.append(int(1))
# for i in range(0,27):
#     l.append(int(2))
# for i in range(0,27):
#     l.append(int(3))

# l=np.array(l)

# from sklearn import preprocessing, cross_validation, svm
# import numpy as np
# from sklearn                        import metrics, svm
# from sklearn.linear_model           import LinearRegression
# from sklearn.linear_model           import LogisticRegression
# from sklearn.tree                   import DecisionTreeClassifier
# from sklearn.neighbors              import KNeighborsClassifier
# from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
# from sklearn.naive_bayes            import GaussianNB
# from sklearn.svm                    import SVC
# from sklearn import linear_model
# import statistics 

# X = energy_feature
# #print(np.shape(energy_feature))
# X=preprocessing.scale(X)
# y=l
# #print(np.shape(y))
# score=[]
# print('4 Class problem')

# clf=KNeighborsClassifier(n_neighbors=4)
# from sklearn.model_selection import StratifiedKFold
# skf = StratifiedKFold(n_splits=5, random_state=None)
# # X is the feature set and y is the target
# for train_index, val_index in skf.split(X,y): 
# #     print("Train:", train_index, "Validation:", val_index) 
#     X_train, X_test = X[train_index], X[val_index] 
#     y_train, y_test = y[train_index], y[val_index]
# #     print(y_train)
#     clf.fit(X_train, y_train)
#     confidence = clf.score(X_test, y_test)
#     score.append(confidence)
# #print(score)
# print('KNN:',statistics.mean(score))


# clf=MLPClassifier()
# from sklearn.model_selection import StratifiedKFold
# skf = StratifiedKFold(n_splits=5, random_state=None)
# # X is the feature set and y is the target
# for train_index, val_index in skf.split(X,y): 
# #     print("Train:", train_index, "Validation:", val_index) 
#     X_train, X_test = X[train_index], X[val_index] 
#     y_train, y_test = y[train_index], y[val_index]
# #    print(np.shape(hjorth_feature)) print(y_train)
#     clf.fit(X_train, y_train)
#     confidence = clf.score(X_test, y_test)
#     score.append(confidence)
# #print(score)
# print('MLP:',statistics.mean(score))


# #value=60%

# %%
# in feature extraction, s is reset after 27 trials
