# %%
import glob
import os
import numpy as np
# %matplotlib notebook
from numpy import sqrt
import matplotlib.pyplot as plt
import scipy as sp
import math
import scipy

import scipy.io as io
import pdb
import scipy.signal as sig
import h5py
import signal
import csv

file_list = glob.glob("*.txt")

rdirection={'s1':[],'s2':[],'s3':[]}
ldirection={'s1':[],'s2':[],'s3':[]}
udirection={'s1':[],'s2':[],'s3':[]}
ddirection={'s1':[],'s2':[],'s3':[]}

d0arr=[]
d1arr=[]
d2arr=[]
r0arr=[]
r1arr=[]
r2arr=[]
l0arr=[]
l1arr=[]
l2arr=[]
u0arr=[]
u1arr=[]
u2arr=[]

#define and intitiaize multi-d array
#values are the min value in each speeds
d0arr=np.zeros((9,4,771))
d1arr=np.zeros((9,4,410))
d2arr=np.zeros((9,4,290))

u0arr=np.zeros((9,4,771))
u1arr=np.zeros((9,4,410))
u2arr=np.zeros((9,4,290))

l0arr=np.zeros((9,4,771))
l1arr=np.zeros((9,4,410))
l2arr=np.zeros((9,4,290))

r0arr=np.zeros((9,4,771))
r1arr=np.zeros((9,4,410))
r2arr=np.zeros((9,4,290))


arr=[]
for file_name in file_list:
    #print(type(file_list))
    #print(file_list)
    i=0
    flag=0
    i=0
    j=0
    array=[]
    c1=[]
    c2=[]
    c3=[]
    c4=[]
    timestamps=[]
    file=open(file_name,"r")
    for line in file:
        #print(array[0])
        if i>=1280:
            array=line.split(",")
            timestamps.append(float(j)/256*1000)
            j=j+1
            #print(array)
            #print(len(array))
            c1.append(float(array[1]))
            c2.append(float(array[2]))
            c3.append(float(array[3]))
            c4.append(float(array[4]))
        i=i+1
    c1=scipy.signal.detrend(c1, axis=-1, type='linear', bp= [i for i in range(0,len(c1),20)])
    c2=scipy.signal.detrend(c2, axis=-1, type='linear', bp= [i for i in range(0,len(c1),20)])
    c3=scipy.signal.detrend(c3, axis=-1, type='linear', bp= [i for i in range(0,len(c1),20)])
    c4=scipy.signal.detrend(c4, axis=-1, type='linear', bp= [i for i in range(0,len(c1),20)])
    
    #to get speed and trial number
    speed=int(file_name[9])-1
    
    trial=int(file_name[11])
    trial=trial+(3)*(int(file_name[7])-1)-1
        

    #truncating the values according to the speeds
    direction=file_name[6]
    if direction == 'r':
        dir=1
        if speed==0:
            c1=c1[0:771]
            c2=c2[0:771]
            c3=c3[0:771]
            c4=c4[0:771]
            r0arr[trial][0]=c1
            r0arr[trial][1]=c2
            r0arr[trial][2]=c3
            r0arr[trial][3]=c4
        if speed==1:
            c1=c1[0:410]
            c2=c2[0:410]
            c3=c3[0:410]
            c4=c4[0:410]
            r1arr[trial][0]=c1
            r1arr[trial][1]=c2
            r1arr[trial][2]=c3
            r1arr[trial][3]=c4
        if speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            r2arr[trial][0]=c1
            r2arr[trial][1]=c2
            r2arr[trial][2]=c3
            r2arr[trial][3]=c4
            
    elif direction =='d':
        dir=2
        if speed==0:
            c1=c1[0:771]
            c2=c2[0:771]
            c3=c3[0:771]
            c4=c4[0:771]
            d0arr[trial][0]=c1
            d0arr[trial][1]=c2
            d0arr[trial][2]=c3
            d0arr[trial][3]=c4

        if speed==1:
            c1=c1[0:410]
            c2=c2[0:410]
            c3=c3[0:410]
            c4=c4[0:410]
            d1arr[trial][0]=c1
            d1arr[trial][1]=c2
            d1arr[trial][2]=c3
            d1arr[trial][3]=c4
        if speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            d2arr[trial][0]=c1
            d2arr[trial][1]=c2
            d2arr[trial][2]=c3
            d2arr[trial][3]=c4
            
    if direction == 'l':
        dir=3
        if speed==0:
            c1=c1[0:771]
            c2=c2[0:771]
            c3=c3[0:771]
            c4=c4[0:771]
            l0arr[trial][0]=c1
            l0arr[trial][1]=c2
            l0arr[trial][2]=c3
            l0arr[trial][3]=c4
        if speed==1:
            c1=c1[0:410]
            c2=c2[0:410]
            c3=c3[0:410]
            c4=c4[0:410]
            l1arr[trial][0]=c1
            l1arr[trial][1]=c2
            l1arr[trial][2]=c3
            l1arr[trial][3]=c4
        if speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            l2arr[trial][0]=c1
            l2arr[trial][1]=c2
            l2arr[trial][2]=c3
            l2arr[trial][3]=c4
            
    elif direction =='u':
        dir=4
        if speed==0:
            c1=c1[0:771]
            c2=c2[0:771]
            c3=c3[0:771]
            c4=c4[0:771]
            u0arr[trial][0]=c1
            u0arr[trial][1]=c2
            u0arr[trial][2]=c3
            u0arr[trial][3]=c4
        if speed==1:
            c1=c1[0:410]
            c2=c2[0:410]
            c3=c3[0:410]
            c4=c4[0:410]
            u1arr[trial][0]=c1
            u1arr[trial][1]=c2
            u1arr[trial][2]=c3
            u1arr[trial][3]=c4
        if speed==2:
            c1=c1[0:290]
            c2=c2[0:290]
            c3=c3[0:290]
            c4=c4[0:290]
            u2arr[trial][0]=c1
            u2arr[trial][1]=c2
            u2arr[trial][2]=c3
            u2arr[trial][3]=c4

       
rdirection['s1'].append(r0arr)
rdirection['s2'].append(r1arr)
rdirection['s3'].append(r2arr)

ldirection['s1'].append(r0arr)
ldirection['s2'].append(r1arr)
ldirection['s3'].append(r2arr)

udirection['s1'].append(r0arr)
udirection['s2'].append(r1arr)
udirection['s3'].append(r2arr)

ddirection['s1'].append(r0arr)
ddirection['s2'].append(r1arr)
ddirection['s3'].append(r2arr)

# %%
sp.io.savemat('right.mat',rdirection)
sp.io.savemat('down.mat',ddirection)
sp.io.savemat('up.mat',udirection)
sp.io.savemat('left.mat',ldirection)
